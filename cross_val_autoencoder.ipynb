# %%
from trainer import Trainer
from datasets import EEGDataset
import torch
from torch.utils.tensorboard import SummaryWriter
from torch.nn import functional as F
import numpy as np
from sklearn.metrics import roc_auc_score
from early_stopping import EarlyStopping
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold,GroupShuffleSplit,GroupKFold
from torch.utils.data import DataLoader, ConcatDataset
from models import EEGAutoencoder,EEG3DDeformAutoencoder, EEG3DAutoencoder,EEGDeformAutoencoder
from torch import nn
import pandas as pd
import random
import os

def warn(*args, **kwargs):
    pass


import warnings

warnings.warn = warn

# %%
SEED =0
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %%
dataset = EEGDataset('../../../data/MDD_EEG/eeg/preprocessing/spectrums/full.csv', is_3D =False)

# %%
#dataset.data

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
def seed_worker(worker_id):
    # worker_seed = torch.initial_seed() % 2**32
    np.random.seed(SEED)
    random.seed(SEED)

# %%
def cross_validation(dataset,experiment_name,learning_rate =1e-4, k_folds=10, num_epochs=50, device='cuda:1'):
    random_seed = 0 # or any of your favorite number
    num_workers =8
    set_seed(random_seed)
    g = torch.Generator()
    g.manual_seed(random_seed)
    kfold = GroupKFold(n_splits=k_folds)
    best_scores, reconstr_losses =[], []
    for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset, None, dataset.data['unique_id'])):
        print(f'FOLD {fold}')
        print('--------------------------------')
        print(test_ids)
        train_dataset =torch.utils.data.Subset(dataset,train_ids)
        val_dataset =torch.utils.data.Subset(dataset,test_ids)
        
        train_loader = torch.utils.data.DataLoader(
            train_dataset,
            num_workers=num_workers,
            worker_init_fn=seed_worker,
            generator=g,
            drop_last=True,
            batch_size=4)
        test_loader = torch.utils.data.DataLoader(
            val_dataset,
            num_workers=num_workers,
            worker_init_fn=seed_worker,
            generator=g,
            drop_last=True,
            batch_size=4)

        model = EEGDeformAutoencoder(hidden_layers=[32,64]).to(device)
        criterion = nn.MSELoss()
        cr_loss = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                                     weight_decay=1e-1)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=1000)
        trainer = Trainer(num_epochs, f'{experiment_name}-fold-{fold}',
                 model, criterion, cr_loss, optimizer, scheduler,device =device,seed=random_seed)
        best_score_acc, reconst_loss =trainer.train(train_loader,test_loader)
        best_scores.append(best_score_acc)
        reconstr_losses.append(reconst_loss)
    return  best_scores,reconstr_losses

# %%
best_scores,reconstr_losses =cross_validation(dataset,"runs/deform-2D-autoencoder-cross-validation")
# Out:
# FOLD 0
# --------------------------------
# [  0   3  18  31  34  41  50  51  53  70  73  77 102 132 133 143 148 154
#  162 164 211 215 219 231 243 259 262 263 292 296]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.714286).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.714286 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.750000).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 1
# --------------------------------
# [  8  14  37  40  58  79  83  90  93  95  99 109 113 114 115 117 126 165
#  168 199 220 221 228 236 240 245 253 275 279 286]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.535714).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# Accuracy score inscreased (0.678571 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.714286).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 2
# --------------------------------
# [  5   6   9  11  26  29  42  56  59  69  82 108 110 118 151 157 161 170
#  174 178 182 183 195 203 217 255 276 280 285 297]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.464286).  Saving model ...
# Accuracy score inscreased (0.464286 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# Accuracy score inscreased (0.642857 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.785714).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# FOLD 3
# --------------------------------
# [ 15  19  22  30  44  47  48  62  64  87 121 123 125 137 145 179 187 226
#  227 237 238 241 244 246 247 249 265 269 271 273]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.714286).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 4
# --------------------------------
# [  2   7  10  24  25  39  46  61  65  74  76  94  97 104 105 141 142 149
#  159 167 181 188 192 193 200 213 216 233 252 274]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# FOLD 5
# --------------------------------
# [ 27  32  36  68  98 124 131 135 136 138 144 150 173 175 176 196 201 202
#  204 223 225 230 239 256 261 283 287 289 291 293]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.464286).  Saving model ...
# Accuracy score inscreased (0.464286 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.678571).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 6
# --------------------------------
# [  4  17  28  35  49  52  54  57  60  80  84  92 112 119 122 139 160 180
#  186 206 214 218 248 250 251 257 260 268 284 288]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.392857).  Saving model ...
# Accuracy score inscreased (0.392857 --> 0.464286).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.464286 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.607143).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# FOLD 7
# --------------------------------
# [  1  21  33  55  66  67  71  75  81  85  88  96 127 129 134 152 153 155
#  177 209 210 212 222 224 229 235 264 270 282 294]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.535714).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.535714 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 8
# --------------------------------
# [ 16  20  43  45  63  86  91 100 107 130 140 147 171 184 190 191 205 207
#  242 254 258 266 267 272 277 278 281 290 295]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.607143).  Saving model ...
# Accuracy score inscreased (0.607143 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.714286).  Saving model ...
# Accuracy score inscreased (0.714286 --> 0.750000).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# EarlyStopping counter: 13 out of 15
# EarlyStopping counter: 14 out of 15
# EarlyStopping counter: 15 out of 15
# Early stopping
# FOLD 9
# --------------------------------
# [ 12  13  23  38  72  78  89 101 103 106 111 116 120 128 146 156 158 163
#  166 169 172 185 189 194 197 198 208 232 234]
# EEGDeformAutoencoder(
#   (encoder): Sequential(
#     (0): DeformableConv2d(
#       (offset_conv): Conv2d(15, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(15, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(15, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): DeformableConv2d(
#       (offset_conv): Conv2d(32, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (modulator_conv): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (regular_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ELU(alpha=True)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(32, 15, kernel_size=(2, 2), stride=(2, 2))
#     (4): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=True)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (fc): Linear(in_features=4096, out_features=2, bias=True)
# )
# Accuracy score inscreased (-inf --> 0.392857).  Saving model ...
# Accuracy score inscreased (0.392857 --> 0.500000).  Saving model ...
# Accuracy score inscreased (0.500000 --> 0.535714).  Saving model ...
# Accuracy score inscreased (0.535714 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.571429 --> 0.571429).  Saving model ...
# Accuracy score inscreased (0.571429 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# Accuracy score inscreased (0.642857 --> 0.642857).  Saving model ...
# Accuracy score inscreased (0.642857 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.678571).  Saving model ...
# Accuracy score inscreased (0.678571 --> 0.714286).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15

# %%
np.mean(best_scores)
# Out:
# 0.6892857142857143

# %%
best_scores
# Out:
# [0.75,
#  0.7142857142857143,
#  0.7857142857142857,
#  0.7142857142857143,
#  0.6071428571428571,
#  0.6785714285714286,
#  0.6071428571428571,
#  0.5714285714285714,
#  0.75,
#  0.7142857142857143]

# %%
np.std(best_scores)
# Out:
# 0.06785714285714287

# %%
np.mean([reconst_loss.detach().cpu().numpy() for reconst_loss in reconstr_losses])
# Out:
# 0.5447323

# %%
np.std([reconst_loss.detach().cpu().numpy() for reconst_loss in reconstr_losses])
# Out:
# 0.901809

# %%
[reconst_loss.detach().cpu().numpy() for reconst_loss in reconstr_losses]
# Out:
# [array(0.23343945, dtype=float32),
#  array(0.40892613, dtype=float32),
#  array(0.16485944, dtype=float32),
#  array(0.23378865, dtype=float32),
#  array(0.14494827, dtype=float32),
#  array(0.31304044, dtype=float32),
#  array(0.21584284, dtype=float32),
#  array(0.3161478, dtype=float32),
#  array(3.2403498, dtype=float32),
#  array(0.17598024, dtype=float32)]
